# %% [markdown]
# # bussiness problem - banglor house price prediction

# %% [markdown]
# # support vecctor regession -  supervised machinne learning

# %%
# import pandas as pd
import pandas as pd

# %%
df=pd.read_csv("/content/banglor house data use support vector regression.csv")

# %%
df.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0     3      2.0  150.0          1672.0    3     8971.291866
# 1     3      3.0  149.0          1750.0    3     8514.285714
# 2     3      2.0  150.0          1750.0    3     8571.428571
# 3     2      2.0   40.0          1250.0    2     3200.000000
# 4     2      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
df.shape
# Out:
# (7120, 108)

# %% [markdown]
# # split data

# %%
x=df.drop('price',axis=1) # drop dependent future
y=df['price']
x.shape , y.shape
# Out:
# ((7120, 107), (7120,))

# %% [markdown]
# train test split data

# %%
#train_test split jdata
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=51)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((5696, 107), (1424, 107), (5696,), (1424,))

# %% [markdown]
# # SUPPORT VECTOOR REGRESSION

# %%
from sklearn.svm import SVR

# %%
SR=SVR(kernel="rbf" ) # by default kernal
SR.fit(x_train,y_train)
# Out:
# SVR()

# %%
SR.score(x_test,y_test)
# Out:
# 0.3266145829415533

# %%
SR=SVR(kernel="linear" ) #check linear kernal
SR.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
SR.score(x_test,y_test)  #score
# Out:
# 0.8231511370588148

# %%
y_ped=SR.predict(x_test) # predict
y_ped
# Out:
# array([ 79.16335544,  31.26184218, 127.50103768, ...,  27.43025355,
#         77.15661426, 175.2704508 ])

# %%
y_test
# Out:
# 2435     80.00
# 3113     40.00
# 426     120.00
# 1124     79.00
# 1161     45.00
#          ...
# 2078     28.34
# 6855     84.00
# 4381     32.00
# 3862     63.00
# 43      180.00
# Name: price, Length: 1424, dtype: float64

# %% [markdown]
# root mean squaare

# %%
#finnd mean squre error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
mse=mean_squared_error(y_test,SR.predict(x_test))
rmse=np.sqrt(mse)

# %%
rmse , mse
# Out:
# (59.61051120727348, 3553.4130463924776)

# %%
print("thanku.........")
# Out:
# thanku.........
